# %%
import pandas as pd

# %%
df1 = pd.read_csv('ganjar[06-01-2023].csv')
df2 = pd.read_csv('ganjar[06-02-2023].csv')
df3 = pd.read_csv('ganjar[06-03-2023].csv')
# df4 = pd.read_csv('ganjar[06-04-2023].csv')
df5 = pd.read_csv('ganjar[06-05-2023].csv')
df6 = pd.read_csv('ganjar[06-06-2023].csv')
df7 = pd.read_csv('ganjar[06-07-2023].csv')
df8 = pd.read_csv('ganjar[06-08-2023].csv')
df9 = pd.read_csv('ganjar[06-09-2023].csv')
df10 = pd.read_csv('ganjar[06-10-2023].csv')
df11 = pd.read_csv('ganjar[06-11-2023].csv')
df12 = pd.read_csv('ganjar[06-12-2023].csv')
df13 = pd.read_csv('ganjar[06-13-2023].csv')
df14 = pd.read_csv('ganjar[06-14-2023].csv')
# df15 = pd.read_csv('ganjar[06-15-2023].csv')
df16 = pd.read_csv('ganjar[06-16-2023].csv')
df17 = pd.read_csv('ganjar[06-17-2023].csv')
df18 = pd.read_csv('ganjar[06-18-2023].csv')
df19 = pd.read_csv('ganjar[06-19-2023].csv')
df20 = pd.read_csv('ganjar[06-20-2023].csv')
df21 = pd.read_csv('ganjar[06-21-2023].csv')
df22 = pd.read_csv('ganjar[06-22-2023].csv')
df23 = pd.read_csv('ganjar[06-23-2023].csv')
df24 = pd.read_csv('ganjar[06-24-2023].csv')
df25 = pd.read_csv('ganjar[06-25-2023].csv')
df26 = pd.read_csv('ganjar[06-26-2023].csv')
df27 = pd.read_csv('ganjar[06-27-2023].csv')
df28 = pd.read_csv('ganjar[06-28-2023].csv')
df29 = pd.read_csv('ganjar[06-29-2023].csv')
df30 = pd.read_csv('ganjar[06-30-2023].csv')

# %%
print('ganjar[06-01-2023] : ',df1.shape)
print('ganjar[06-02-2023] : ',df2.shape)
print('ganjar[06-03-2023] : ',df3.shape)
# print('ganjar[06-04-2023] : ',df4.shape)
print('ganjar[06-05-2023] : ',df5.shape)
print('ganjar[06-06-2023] : ',df6.shape)
print('ganjar[06-07-2023] : ',df7.shape)
print('ganjar[06-08-2023] : ',df8.shape)
print('ganjar[06-09-2023] : ',df9.shape)
print('ganjar[06-10-2023] : ',df10.shape)
print('ganjar[06-11-2023] : ',df11.shape)
print('ganjar[06-12-2023] : ',df12.shape)
print('ganjar[06-13-2023] : ',df13.shape)
print('ganjar[06-14-2023] : ',df14.shape)
# print('ganjar[06-15-2023] : ',df15.shape)
print('ganjar[06-16-2023] : ',df16.shape)
print('ganjar[06-17-2023] : ',df17.shape)
print('ganjar[06-18-2023] : ',df18.shape)
print('ganjar[06-19-2023] : ',df19.shape)
print('ganjar[06-20-2023] : ',df20.shape)
print('ganjar[06-21-2023] : ',df21.shape)
print('ganjar[06-22-2023] : ',df22.shape)
print('ganjar[06-23-2023] : ',df23.shape)
print('ganjar[06-24-2023] : ',df24.shape)
print('ganjar[06-25-2023] : ',df25.shape)
print('ganjar[06-26-2023] : ',df26.shape)
print('ganjar[06-27-2023] : ',df27.shape)
print('ganjar[06-28-2023] : ',df28.shape)
print('ganjar[06-29-2023] : ',df29.shape)
print('ganjar[06-30-2023] : ',df30.shape)
# Out:
# ganjar[06-01-2023] :  (100, 6)
# ganjar[06-02-2023] :  (100, 6)
# ganjar[06-03-2023] :  (100, 6)
# ganjar[06-05-2023] :  (100, 6)
# ganjar[06-06-2023] :  (94, 6)
# ganjar[06-07-2023] :  (27, 6)
# ganjar[06-08-2023] :  (100, 6)
# ganjar[06-09-2023] :  (100, 6)
# ganjar[06-10-2023] :  (100, 6)
# ganjar[06-11-2023] :  (100, 6)
# ganjar[06-12-2023] :  (90, 6)
# ganjar[06-13-2023] :  (99, 6)
# ganjar[06-14-2023] :  (100, 6)
# ganjar[06-16-2023] :  (100, 6)
# ganjar[06-17-2023] :  (100, 6)
# ganjar[06-18-2023] :  (100, 6)
# ganjar[06-19-2023] :  (100, 6)
# ganjar[06-20-2023] :  (100, 6)
# ganjar[06-21-2023] :  (97, 6)
# ganjar[06-22-2023] :  (100, 6)
# ganjar[06-23-2023] :  (96, 6)
# ganjar[06-24-2023] :  (100, 6)
# ganjar[06-25-2023] :  (100, 6)
# ganjar[06-26-2023] :  (100, 6)
# ganjar[06-27-2023] :  (92, 6)
# ganjar[06-28-2023] :  (91, 6)
# ganjar[06-29-2023] :  (97, 6)
# ganjar[06-30-2023] :  (100, 6)

# %%
df_concat = pd.concat([df1, df2, df3, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26, df27, df28, df29, df30])
df_concat.shape
# df_concat
# Out:
# (2683, 6)

# %%
df_concat.to_csv('ganjar6.csv')
df_concat
# Out:
#     Unnamed: 0                   id                 date  \
# 0            0  1664284281269800961  2023-06-01 14:54:28
# 1            1  1664284242849972225  2023-06-01 14:54:19
# 2            2  1664284215817666562  2023-06-01 14:54:12
# 3            3  1664284189934645253  2023-06-01 14:54:06
# 4            4  1664284185543200772  2023-06-01 14:54:05
# ..         ...                  ...                  ...
# 95          95  1674773763538423810  2023-06-30 13:35:55
# 96          96  1674773752943624192  2023-06-30 13:35:53
# 97          97  1674773730420199426  2023-06-30 13:35:47
# 98          98  1674773707791945734  2023-06-30 13:35:42
# 99          99  1674773683481772037  2023-06-30 13:35:36
#
#                                                  text                   place  \
# 0   RT @IwanKunik: Keren pak Ganjar Pranowo 👍👍 ker...                     NaN
# 1   RT @otnayram_me: Di alun alun Pancasila Cepogo...                     NaN
# ...
